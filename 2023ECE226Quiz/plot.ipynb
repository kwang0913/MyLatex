# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Create a red rectangle that covers the first quadrant
rectangle1 = patches.Rectangle((1,-1), 4, 4, facecolor='yellow')
rectangle2 = patches.Rectangle((-1,1), 4, 4, facecolor='yellow')

# Create a white rectangle that covers the area 0<x<1 and 0<y<1
rectangle3 = patches.Rectangle((0,0), 1, 1, facecolor='white')

# Add the rectangles to the plot
ax.add_patch(rectangle1)
ax.add_patch(rectangle2)
ax.add_patch(rectangle3)

# Create a range of x values
x = np.linspace(-10, 10, 400)

# Calculate the corresponding y values
y = 2 - x

# Color the area where y > 2 - x
ax.fill_between(x, y, 10, where=y<10, color='red', alpha=0.3)

# Set the x and y limits to show the Cartesian plane
ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)

# Draw x and y axis
ax.axhline(0, color='black',linewidth=0.5)
ax.axvline(0, color='black',linewidth=0.5)

# Set labels
ax.set_xlabel('$X_1$')
ax.set_ylabel('$X_2$')

# Show the plot
plt.savefig('plot1.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Create a red rectangle that covers the first quadrant
rectangle1 = patches.Rectangle((0,0), 4, 4, facecolor='red')

# Create a white rectangle that covers the area 0<x<1 and 0<y<1
rectangle2 = patches.Rectangle((0,0), 1, 1, facecolor='white')

# Add the rectangles to the plot
ax.add_patch(rectangle1)
ax.add_patch(rectangle2)

# Set the x and y limits to show the Cartesian plane
ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)

# Draw x and y axis
ax.axhline(0, color='black',linewidth=0.5)
ax.axvline(0, color='black',linewidth=0.5)

# Set labels
ax.set_xlabel('$X_1$')
ax.set_ylabel('$X_2$')

# Show the plot
plt.savefig('plot2.eps')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a grid of points in the y1-y2 plane
y2, y1 = np.mgrid[0:1:0.01, 0:1:0.01]

# Define the region: y2 < y1 < y2 + 1/4
region = (y2 < y1) & (y1 < y2 + 0.25)

plt.figure(figsize=(8, 8))
plt.imshow(region, extent=(0,1,0,1), origin='lower', cmap='Greys', alpha=0.3)

plt.title("Region defined by: $y_2 < y_1 < y_2 + \\frac{1}{4}$")
plt.xlabel("$y_1$")
plt.ylabel("$y_2$")
plt.grid(True)
plt.savefig('plot3.eps')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a grid of points in the y1-y2 plane
y2, y1 = np.mgrid[0:1:0.0025, 0:1:0.0025]

# Define the region: y2 < y1 < y2 + 1/4
region = (y1 < y2+1/12) & (y1 > y2 - 1/12)

plt.figure(figsize=(8, 8))
plt.imshow(region, extent=(0,1,0,1), origin='lower', cmap='Greys', alpha=0.3)

plt.title("Region defined by: $|X_1 -X_2|\leq \\frac{1}{4}$")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.grid(True)
plt.savefig('plot4.eps')
plt.show()
